# %%
import tensorflow as tf
import numpy as np
import sys
from random import randint
import datetime
from sklearn.utils import shuffle
import pickle
import os
# Removes an annoying Tensorflow warning
os.environ['TF_CPP_MIN_LOG_LEVEL']='2'

def createTrainingMatrices(conversationFileName, wList, maxLen):
    conversationDictionary = np.load(conversationFileName,allow_pickle=True).item()
    numExamples = len(conversationDictionary)
    xTrain = np.zeros((numExamples, maxLen), dtype='int32')
    yTrain = np.zeros((numExamples, maxLen), dtype='int32')
    for index,(key,value) in enumerate(conversationDictionary.items()):
        # Will store integerized representation of strings here (initialized as padding)
        encoderMessage = np.full((maxLen), wList.index('<pad>'), dtype='int32')
        decoderMessage = np.full((maxLen), wList.index('<pad>'), dtype='int32')
        # Getting all the individual words in the strings
        keySplit = key.split()
        valueSplit = value.split()
        keyCount = len(keySplit)
        valueCount = len(valueSplit)
        # Throw out sequences that are too long or are empty
        if (keyCount > (maxLen - 1) or valueCount > (maxLen - 1) or valueCount == 0 or keyCount == 0):
            continue
        # Integerize the encoder string
        for keyIndex, word in enumerate(keySplit):
            try:
                encoderMessage[keyIndex] = wList.index(word)
            except ValueError:
                # TODO: This isnt really the right way to handle this scenario
                encoderMessage[keyIndex] = 0
        encoderMessage[keyIndex + 1] = wList.index('<EOS>')
        # Integerize the decoder string
        for valueIndex, word in enumerate(valueSplit):
            try:
                decoderMessage[valueIndex] = wList.index(word)
            except ValueError:
                decoderMessage[valueIndex] = 0
        decoderMessage[valueIndex + 1] = wList.index('<EOS>')
        xTrain[index] = encoderMessage
        yTrain[index] = decoderMessage
    # Remove rows with all zeros
    yTrain = yTrain[~np.all(yTrain == 0, axis=1)]
    xTrain = xTrain[~np.all(xTrain == 0, axis=1)]
    numExamples = xTrain.shape[0]
    return numExamples, xTrain, yTrain

def getTrainingBatch(localXTrain, localYTrain, localBatchSize, maxLen):
    num = randint(0,numTrainingExamples - localBatchSize - 1)
    arr = localXTrain[num:num + localBatchSize]
    labels = localYTrain[num:num + localBatchSize]
    # Reversing the order of encoder string apparently helps as per 2014 paper
    reversedList = list(arr)
    for index,example in enumerate(reversedList):
        reversedList[index] = list(reversed(example))

    # Lagged labels are for the training input into the decoder
    laggedLabels = []
    EOStokenIndex = wordList.index('<EOS>')
    padTokenIndex = wordList.index('<pad>')
    for example in labels:
        eosFound = np.argwhere(example==EOStokenIndex)[0]
        shiftedExample = np.roll(example,1)
        shiftedExample[0] = EOStokenIndex
        # The EOS token was already at the end, so no need for pad
        if (eosFound != (maxLen - 1)):
            shiftedExample[eosFound+1] = padTokenIndex
        laggedLabels.append(shiftedExample)

    # Need to transpose these
    reversedList = np.asarray(reversedList).T.tolist()
    labels = labels.T.tolist()
    laggedLabels = np.asarray(laggedLabels).T.tolist()
    return reversedList, labels, laggedLabels

def translateToSentences(inputs, wList, encoder=False):
    EOStokenIndex = wList.index('<EOS>')
    padTokenIndex = wList.index('<pad>')
    numStrings = len(inputs[0])
    numLengthOfStrings = len(inputs)
    listOfStrings = [''] * numStrings
    for mySet in inputs:
        for index,num in enumerate(mySet):
            if (num != EOStokenIndex and num != padTokenIndex):
                if (encoder):
                    # Encodings are in reverse!
                    listOfStrings[index] = wList[num] + " " + listOfStrings[index]
                else:
                    listOfStrings[index] = listOfStrings[index] + " " + wList[num]
    listOfStrings = [string.strip() for string in listOfStrings]
    return listOfStrings

def getTestInput(inputMessage, wList, maxLen):
    encoderMessage = np.full((maxLen), wList.index('<pad>'), dtype='int32')
    inputSplit = inputMessage.lower().split()
    for index,word in enumerate(inputSplit):
        try:
            encoderMessage[index] = wList.index(word)
        except ValueError:
            continue
    encoderMessage[index + 1] = wList.index('<EOS>')
    encoderMessage = encoderMessage[::-1]
    encoderMessageList=[]
    for num in encoderMessage:
        encoderMessageList.append([num])
    return encoderMessageList

def idsToSentence(ids, wList):
    EOStokenIndex = wList.index('<EOS>')
    padTokenIndex = wList.index('<pad>')
    myStr = ""
    listOfResponses=[]
    for num in ids:
        if (num[0] == EOStokenIndex or num[0] == padTokenIndex):
            listOfResponses.append(myStr)
            myStr = ""
        else:
            myStr = myStr + wList[num[0]] + " "
    if myStr:
        listOfResponses.append(myStr)
    listOfResponses = [i for i in listOfResponses if i]
    return listOfResponses

# Hyperparamters
batchSize = 24
maxEncoderLength = 15
maxDecoderLength = maxEncoderLength
lstmUnits = 112
embeddingDim = lstmUnits
numLayersLSTM = 3
numIterations = 50000

# Loading in all the data structures
with open("wordList.txt", "rb") as fp:
    wordList = pickle.load(fp)

vocabSize = len(wordList)

# If you've run the entirety of word2vec.py then these lines will load in
# the embedding matrix.
if (os.path.isfile('embeddingMatrix.npy')):
    wordVectors = np.load('embeddingMatrix.npy')
    wordVecDimensions = wordVectors.shape[1]
else:
   # question = 'Since we cant find an embedding matrix, how many dimensions do you want your word vectors to be?: '
    wordVecDimensions = 10

# Add two entries to the word vector matrix. One to represent padding tokens,
# and one to represent an end of sentence token
padVector = np.zeros((1, wordVecDimensions), dtype='int32')
EOSVector = np.ones((1, wordVecDimensions), dtype='int32')
if (os.path.isfile('embeddingMatrix.npy')):
    wordVectors = np.concatenate((wordVectors,padVector), axis=0)
    wordVectors = np.concatenate((wordVectors,EOSVector), axis=0)

# Need to modify the word list as well
wordList.append('<pad>')
wordList.append('<EOS>')
vocabSize = vocabSize + 2

if (os.path.isfile('Seq2SeqXTrain.npy') and os.path.isfile('Seq2SeqYTrain.npy')):
    xTrain = np.load('Seq2SeqXTrain.npy')
    yTrain = np.load('Seq2SeqYTrain.npy')
    print('Finished loading training matrices')
    numTrainingExamples = xTrain.shape[0]
else:
    numTrainingExamples, xTrain, yTrain = createTrainingMatrices('./chatdata/comrepTrain2015-01.npy', wordList, maxEncoderLength)
    np.save('Seq2SeqXTrain.npy', xTrain)
    np.save('Seq2SeqYTrain.npy', yTrain)
    print('Finished creating training matrices')

tf.reset_default_graph()

# Create the placeholders
encoderInputs = [tf.placeholder(tf.int32, shape=(None,)) for i in range(maxEncoderLength)]
decoderLabels = [tf.placeholder(tf.int32, shape=(None,)) for i in range(maxDecoderLength)]
decoderInputs = [tf.placeholder(tf.int32, shape=(None,)) for i in range(maxDecoderLength)]
feedPrevious = tf.placeholder(tf.bool)

encoderLSTM = tf.nn.rnn_cell.BasicLSTMCell(lstmUnits, state_is_tuple=True)

#encoderLSTM = tf.nn.rnn_cell.MultiRNNCell([singleCell]*numLayersLSTM, state_is_tuple=True)
# Architectural choice of of whether or not to include ^

decoderOutputs, decoderFinalState = tf.contrib.legacy_seq2seq.embedding_rnn_seq2seq(encoderInputs, decoderInputs, encoderLSTM,
                                                            vocabSize, vocabSize, embeddingDim, feed_previous=feedPrevious)

decoderPrediction = tf.argmax(decoderOutputs, 2)

lossWeights = [tf.ones_like(l, dtype=tf.float32) for l in decoderLabels]
loss = tf.contrib.legacy_seq2seq.sequence_loss(decoderOutputs, decoderLabels, lossWeights, vocabSize)
optimizer = tf.train.AdamOptimizer(1e-4).minimize(loss)

sess = tf.Session()
saver = tf.train.Saver()
# If you're loading in a saved model, uncomment the following line and comment out line 202
#saver.restore(sess, tf.train.latest_checkpoint('models/'))
sess.run(tf.global_variables_initializer())

# Uploading results to Tensorboard
tf.summary.scalar('Loss', loss)
merged = tf.summary.merge_all()
logdir = "tensorboard/" + datetime.datetime.now().strftime("%Y%m%d-%H%M%S") + "/"
writer = tf.summary.FileWriter(logdir, sess.graph)

# Some test strings that we'll use as input at intervals during training
encoderTestStrings = ["whats up",
					"hi",
					"hey how are you",
					"what are you up to",
					"that dodgers game was awesome"
					]

zeroVector = np.zeros((1), dtype='int32')

for i in range(numIterations):

    encoderTrain, decoderTargetTrain, decoderInputTrain = getTrainingBatch(xTrain, yTrain, batchSize, maxEncoderLength)
    feedDict = {encoderInputs[t]: encoderTrain[t] for t in range(maxEncoderLength)}
    feedDict.update({decoderLabels[t]: decoderTargetTrain[t] for t in range(maxDecoderLength)})
    feedDict.update({decoderInputs[t]: decoderInputTrain[t] for t in range(maxDecoderLength)})
    feedDict.update({feedPrevious: False})

    curLoss, _, pred = sess.run([loss, optimizer, decoderPrediction], feed_dict=feedDict)

    if (i % 50 == 0):
        print('Current loss:', curLoss, 'at iteration', i)
        summary = sess.run(merged, feed_dict=feedDict)
        writer.add_summary(summary, i)
    if (i % 25 == 0 and i != 0):
        num = randint(0,len(encoderTestStrings) - 1)
        print(encoderTestStrings[num])
        inputVector = getTestInput(encoderTestStrings[num], wordList, maxEncoderLength);
        feedDict = {encoderInputs[t]: inputVector[t] for t in range(maxEncoderLength)}
        feedDict.update({decoderLabels[t]: zeroVector for t in range(maxDecoderLength)})
        feedDict.update({decoderInputs[t]: zeroVector for t in range(maxDecoderLength)})
        feedDict.update({feedPrevious: True})
        ids = (sess.run(decoderPrediction, feed_dict=feedDict))
        print(idsToSentence(ids, wordList))

    if (i % 10000 == 0 and i != 0):
        savePath = saver.save(sess, "models/pretrained_seq2seq.ckpt", global_step=i)
# Out:
# Finished creating training matrices
# WARNING:tensorflow:From <ipython-input-6-7103ab00bf60>:184: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From /home/mak/anaconda3/envs/codehub/lib/python3.7/site-packages/tensorflow/contrib/legacy_seq2seq/python/ops/seq2seq.py:363: static_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell, unroll=True)`, which is equivalent to this API
# WARNING:tensorflow:From /home/mak/anaconda3/envs/codehub/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /home/mak/anaconda3/envs/codehub/lib/python3.7/site-packages/tensorflow/python/ops/array_grad.py:425: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Current loss: 9.088712 at iteration 0
# hey how are you
# ['A ']
# Current loss: 8.832104 at iteration 50
# what are you up to
# ['9/10 ']
# what are you up to
# ['9/10 ']
# Current loss: 7.3494735 at iteration 100
# hi
# ['9/10 ']
# that dodgers game was awesome
# []
# Current loss: 5.793371 at iteration 150
# hi
# []
# what are you up to
# []
# Current loss: 4.6405964 at iteration 200
# hi
# []
# hey how are you
# []
# Current loss: 4.170627 at iteration 250
# whats up
# []
# whats up
# []
# Current loss: 3.1038437 at iteration 300
# hi
# []
# hi
# []
# Current loss: 3.1362047 at iteration 350
# that dodgers game was awesome
# []
# that dodgers game was awesome
# []
# Current loss: 2.7631495 at iteration 400
# hi
# []
# what are you up to
# []
# Current loss: 3.2428477 at iteration 450
# that dodgers game was awesome
# []
# hi
# []
# Current loss: 3.037419 at iteration 500
# whats up
# []
# what are you up to
# []
# Current loss: 2.6291058 at iteration 550
# hi
# []
# whats up
# []
# Current loss: 2.8833015 at iteration 600
# hi
# []
# hey how are you
# []
# Current loss: 2.9106216 at iteration 650
# that dodgers game was awesome
# []
# that dodgers game was awesome
# []
# Current loss: 2.8420575 at iteration 700
# whats up
# []
# what are you up to
# []
# Current loss: 3.090047 at iteration 750
# hi
# []
# whats up
# []
# Current loss: 2.9528875 at iteration 800
# hey how are you
# []
# what are you up to
# []
# Current loss: 2.9697154 at iteration 850
# hi
# []
# that dodgers game was awesome
# []
# Current loss: 2.7227478 at iteration 900
# hey how are you
# []
# what are you up to
# []
# Current loss: 2.1584303 at iteration 950
# whats up
# []
# what are you up to
# []
# Current loss: 2.8494263 at iteration 1000
# hi
# []
# what are you up to
# []
# Current loss: 2.8877609 at iteration 1050
# hi
# []
# hey how are you
# ['9/10 ']
# Current loss: 2.195906 at iteration 1100
# that dodgers game was awesome
# ['9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 2.2937145 at iteration 1150
# what are you up to
# ['9/10 ']
# what are you up to
# ['9/10 ']
# Current loss: 2.3368237 at iteration 1200
# hi
# ['9/10 ']
# hey how are you
# ['9/10 ']
# Current loss: 2.82366 at iteration 1250
# that dodgers game was awesome
# ['9/10 ']
# whats up
# ['9/10 ']
# Current loss: 2.8203366 at iteration 1300
# that dodgers game was awesome
# ['9/10 ']
# what are you up to
# ['9/10 9/10 ']
# Current loss: 2.3985968 at iteration 1350
# whats up
# ['9/10 ']
# hey how are you
# ['9/10 ']
# Current loss: 2.6518824 at iteration 1400
# that dodgers game was awesome
# ['9/10 ']
# whats up
# ['9/10 ']
# Current loss: 2.6422875 at iteration 1450
# that dodgers game was awesome
# ['9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 1.9837437 at iteration 1500
# what are you up to
# ['9/10 9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 2.7351005 at iteration 1550
# what are you up to
# ['9/10 9/10 ']
# whats up
# ['9/10 ']
# Current loss: 1.9146262 at iteration 1600
# that dodgers game was awesome
# ['9/10 ']
# what are you up to
# ['9/10 9/10 ']
# Current loss: 2.4556892 at iteration 1650
# whats up
# ['9/10 ']
# what are you up to
# ['9/10 9/10 ']
# Current loss: 2.4112267 at iteration 1700
# hi
# ['9/10 ']
# hey how are you
# ['9/10 9/10 ']
# Current loss: 2.5108979 at iteration 1750
# what are you up to
# ['9/10 9/10 ']
# hey how are you
# ['9/10 9/10 ']
# Current loss: 2.6988134 at iteration 1800
# what are you up to
# ['9/10 9/10 ']
# what are you up to
# ['9/10 9/10 ']
# Current loss: 2.051729 at iteration 1850
# what are you up to
# ['9/10 9/10 ']
# hey how are you
# ['9/10 9/10 ']
# Current loss: 2.1438274 at iteration 1900
# hey how are you
# ['9/10 9/10 ']
# whats up
# ['9/10 9/10 ']
# Current loss: 1.874674 at iteration 1950
# what are you up to
# ['9/10 9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 2.199152 at iteration 2000
# hi
# ['9/10 9/10 ']
# what are you up to
# ['9/10 9/10 ']
# Current loss: 2.084283 at iteration 2050
# that dodgers game was awesome
# ['9/10 ']
# whats up
# ['9/10 9/10 ']
# Current loss: 2.2530549 at iteration 2100
# that dodgers game was awesome
# ['9/10 ']
# whats up
# ['9/10 9/10 ']
# Current loss: 1.8572369 at iteration 2150
# whats up
# ['9/10 9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 2.0155187 at iteration 2200
# hey how are you
# ['9/10 9/10 ']
# hi
# ['9/10 9/10 ']
# Current loss: 1.894763 at iteration 2250
# hey how are you
# ['9/10 9/10 ']
# whats up
# ['9/10 9/10 ']
# Current loss: 2.341959 at iteration 2300
# what are you up to
# ['9/10 9/10 ']
# hi
# ['9/10 9/10 ']
# Current loss: 2.4666917 at iteration 2350
# hi
# ['9/10 9/10 ']
# whats up
# ['9/10 ']
# Current loss: 2.0375392 at iteration 2400
# what are you up to
# ['9/10 9/10 ']
# what are you up to
# ['9/10 9/10 ']
# Current loss: 2.427001 at iteration 2450
# that dodgers game was awesome
# ['9/10 ']
# hi
# ['9/10 9/10 ']
# Current loss: 2.2867947 at iteration 2500
# that dodgers game was awesome
# ['9/10 ']
# what are you up to
# ['9/10 9/10 ']
# Current loss: 1.9681941 at iteration 2550
# what are you up to
# ['9/10 9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 2.24178 at iteration 2600
# hey how are you
# ['9/10 9/10 ']
# whats up
# ['9/10 ']
# Current loss: 1.780481 at iteration 2650
# hi
# ['9/10 9/10 ']
# whats up
# ['9/10 ']
# Current loss: 1.7034184 at iteration 2700
# whats up
# ['9/10 ']
# hey how are you
# ['9/10 9/10 ']
# Current loss: 1.6070875 at iteration 2750
# whats up
# ['9/10 ']
# hi
# ['9/10 9/10 ']
# Current loss: 1.8450552 at iteration 2800
# that dodgers game was awesome
# ['9/10 ']
# hi
# ['9/10 9/10 ']
# Current loss: 2.0852516 at iteration 2850
# whats up
# ['9/10 ']
# hey how are you
# ['9/10 9/10 ']
# Current loss: 1.8006605 at iteration 2900
# what are you up to
# ['9/10 9/10 ']
# whats up
# ['9/10 ']
# Current loss: 2.2955625 at iteration 2950
# hey how are you
# ['9/10 9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 2.1883647 at iteration 3000
# hi
# ['9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 1.5110539 at iteration 3050
# what are you up to
# ['9/10 9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 2.0938053 at iteration 3100
# hey how are you
# ['9/10 9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 1.8123673 at iteration 3150
# hey how are you
# ['9/10 9/10 ']
# whats up
# ['9/10 ']
# Current loss: 1.7531996 at iteration 3200
# what are you up to
# ['9/10 ']
# whats up
# ['9/10 ']
# Current loss: 2.4626381 at iteration 3250
# whats up
# ['9/10 ']
# what are you up to
# ['9/10 ']
# Current loss: 1.8878883 at iteration 3300
# whats up
# ['9/10 ']
# hey how are you
# ['9/10 9/10 ']
# Current loss: 1.8699814 at iteration 3350
# what are you up to
# ['9/10 ']
# hey how are you
# ['9/10 9/10 ']
# Current loss: 2.0618775 at iteration 3400
# what are you up to
# ['9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 1.8391981 at iteration 3450
# that dodgers game was awesome
# ['9/10 ']
# whats up
# ['9/10 ']
# Current loss: 1.6748728 at iteration 3500
# what are you up to
# ['9/10 ']
# what are you up to
# ['9/10 ']
# Current loss: 2.1356766 at iteration 3550
# whats up
# ['9/10 ']
# hi
# ['9/10 ']
# Current loss: 1.7208719 at iteration 3600
# hey how are you
# ['9/10 ']
# hi
# ['9/10 ']
# Current loss: 1.7258269 at iteration 3650
# what are you up to
# ['9/10 ']
# hi
# ['9/10 ']
# Current loss: 2.4344285 at iteration 3700
# hi
# ['9/10 ']
# whats up
# ['9/10 ']
# Current loss: 1.6386987 at iteration 3750
# hi
# ['9/10 ']
# hi
# ['9/10 ']
# Current loss: 1.9975485 at iteration 3800
# whats up
# ['9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 1.6819476 at iteration 3850
# that dodgers game was awesome
# ['9/10 ']
# what are you up to
# ['9/10 ']
# Current loss: 2.058979 at iteration 3900
# that dodgers game was awesome
# ['9/10 ']
# what are you up to
# ['9/10 ']
# Current loss: 1.55837 at iteration 3950
# what are you up to
# ['9/10 ']
# hi
# ['9/10 ']
# Current loss: 1.7037587 at iteration 4000
# that dodgers game was awesome
# ['9/10 ']
# whats up
# ['9/10 ']
# Current loss: 1.4604139 at iteration 4050
# hey how are you
# ['9/10 ']
# whats up
# ['9/10 ']
# Current loss: 1.9996816 at iteration 4100
# what are you up to
# ['9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 1.2261105 at iteration 4150
# hi
# ['9/10 ']
# hi
# ['9/10 ']
# Current loss: 1.5382951 at iteration 4200
# hey how are you
# ['9/10 ']
# hi
# ['9/10 ']
# Current loss: 1.7083898 at iteration 4250
# that dodgers game was awesome
# ['9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 1.6576675 at iteration 4300
# whats up
# ['9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 1.4289974 at iteration 4350
# hey how are you
# ['9/10 ']
# what are you up to
# ['9/10 ']
# Current loss: 1.7332473 at iteration 4400
# hey how are you
# ['9/10 ']
# hi
# ['9/10 ']
# Current loss: 1.1696709 at iteration 4450
# whats up
# ['9/10 ']
# whats up
# ['9/10 ']
# Current loss: 1.2881696 at iteration 4500
# that dodgers game was awesome
# ['9/10 ']
# hey how are you
# ['9/10 ']
# Current loss: 1.1375996 at iteration 4550
# hi
# ['9/10 ']
# whats up
# ['9/10 ']
# Current loss: 1.5901209 at iteration 4600
# whats up
# ['9/10 ']
# hey how are you
# ['9/10 ']
# Current loss: 1.6359795 at iteration 4650
# what are you up to
# ['9/10 ']
# hey how are you
# ['9/10 ']
# Current loss: 1.3775154 at iteration 4700
# hey how are you
# ['9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 1.3257424 at iteration 4750
# that dodgers game was awesome
# ['9/10 ']
# what are you up to
# ['9/10 ']
# Current loss: 1.0356623 at iteration 4800
# whats up
# ['9/10 ']
# hey how are you
# ['9/10 ']
# Current loss: 1.2175356 at iteration 4850
# that dodgers game was awesome
# ['9/10 ']
# what are you up to
# ['9/10 ']
# Current loss: 1.276704 at iteration 4900
# hi
# ['9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 0.9932211 at iteration 4950
# whats up
# ['9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 1.4024372 at iteration 5000
# what are you up to
# ['9/10 ']
# whats up
# ['9/10 ']
# Current loss: 1.1636239 at iteration 5050
# hey how are you
# ['I just my my my my you that Cause is his his newlinechar mustach ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 0.9935622 at iteration 5100
# hey how are you
# ['I my my my my my that that needed. needed. needed. needed. Cause is Cause ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 1.0695759 at iteration 5150
# whats up
# ['9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 1.392902 at iteration 5200
# what are you up to
# ['9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 1.5446734 at iteration 5250
# what are you up to
# ['9/10 ']
# hey how are you
# ['I my my my my my about that needed. needed. needed. Cause is though. ']
# Current loss: 0.8882816 at iteration 5300
# whats up
# ['9/10 ']
# what are you up to
# ['9/10 ']
# Current loss: 1.3071475 at iteration 5350
# what are you up to
# ['I my my my momma that needed. needed. Cause is Cause ']
# whats up
# ['9/10 ']
# Current loss: 0.9613525 at iteration 5400
# hey how are you
# ['I my my my my my momma for for that needed. Cause is Cause ']
# whats up
# ['9/10 ']
# Current loss: 1.3100295 at iteration 5450
# what are you up to
# ['I my my my you that needed. Cause is if though. ']
# hey how are you
# ['I my my my my my momma that needed. needed. needed. needed. Cause that Cause ']
# Current loss: 1.2882468 at iteration 5500
# hi
# ['9/10 ']
# what are you up to
# ['I my my my momma that needed. Cause is Cause ']
# Current loss: 1.4068207 at iteration 5550
# that dodgers game was awesome
# ['9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 1.253143 at iteration 5600
# hey how are you
# ['I my my my my my momma about that needed. needed. Cause is Cause ']
# hey how are you
# ['I my my my my my my about that needed. needed. needed. Cause that Cause ']
# Current loss: 1.4818007 at iteration 5650
# hi
# ['I had I my actually of of of 9/10 ']
# hi
# ['I had I my first actually of of ']
# Current loss: 0.9760856 at iteration 5700
# what are you up to
# ["is my my my momma an' 9/10 "]
# what are you up to
# ["is my my my momma an' 9/10 "]
# Current loss: 1.049641 at iteration 5750
# what are you up to
# ["is my my my momma an' 9/10 "]
# hey how are you
# ['I my my my my my momma momma needed. Cause is Cause ']
# Current loss: 1.0126196 at iteration 5800
# that dodgers game was awesome
# ['9/10 ']
# whats up
# ['9/10 ']
# Current loss: 1.446119 at iteration 5850
# hi
# ['I had I my actually of of of 9/10 ']
# whats up
# ['9/10 ']
# Current loss: 1.2261654 at iteration 5900
# whats up
# ['9/10 ']
# hi
# ['I had I my first Liverpool of of ']
# Current loss: 1.5469996 at iteration 5950
# what are you up to
# ['is my my momma momma that needed. Cause is Cause ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 0.93105894 at iteration 6000
# hey how are you
# ['I my my my my my momma momma needed. Cause is Cause ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 1.1804878 at iteration 6050
# whats up
# []
# whats up
# []
# Current loss: 1.225999 at iteration 6100
# hey how are you
# ['I my my my my my momma momma needed. Cause is Cause ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 1.0644342 at iteration 6150
# that dodgers game was awesome
# ['9/10 ']
# what are you up to
# ['is my my momma momma that step is is Ents ']
# Current loss: 1.1287323 at iteration 6200
# hey how are you
# ['I had is that Liverpool that on newlinechar newlinechar newlinechar mustach ']
# what are you up to
# ['is my storing ']
# Current loss: 0.9500561 at iteration 6250
# whats up
# []
# what are you up to
# ['is my storing ']
# Current loss: 1.2324384 at iteration 6300
# hey how are you
# ['I had is that Liverpool that on newlinechar newlinechar newlinechar newlinechar 9/10 ']
# hi
# ['I had I had of ']
# Current loss: 0.6934944 at iteration 6350
# hey how are you
# ['I had is that Liverpool that on newlinechar newlinechar newlinechar newlinechar 9/10 ']
# hey how are you
# ['I had is that Liverpool that on newlinechar newlinechar newlinechar mustach ']
# Current loss: 0.7243614 at iteration 6400
# whats up
# []
# hi
# ['I had I had of ']
# Current loss: 0.919884 at iteration 6450
# hey how are you
# ['I had is that Liverpool that on that on everywhere! ']
# hey how are you
# ['I had is that Liverpool that on that haha. on everywhere! ']
# Current loss: 0.79578453 at iteration 6500
# that dodgers game was awesome
# ['9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 0.96206754 at iteration 6550
# whats up
# []
# what are you up to
# ['is my storing ']
# Current loss: 0.8425357 at iteration 6600
# what are you up to
# ['is my storing ']
# what are you up to
# ['is my storing ']
# Current loss: 0.9157663 at iteration 6650
# hi
# ['I had I had of ']
# whats up
# []
# Current loss: 1.1839998 at iteration 6700
# whats up
# []
# whats up
# []
# Current loss: 0.72954035 at iteration 6750
# what are you up to
# ['is my storing ']
# whats up
# []
# Current loss: 0.8547201 at iteration 6800
# hey how are you
# ['I had is that Liverpool that if on his that they passed though. ']
# whats up
# []
# Current loss: 0.7804584 at iteration 6850
# what are you up to
# ['is my storing ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 0.77081364 at iteration 6900
# whats up
# []
# what are you up to
# ['is my storing ']
# Current loss: 0.64587337 at iteration 6950
# hey how are you
# ['I had is that Liverpool that if on his that they passed though. ']
# hi
# ['I had of that actually ']
# Current loss: 0.87562686 at iteration 7000
# that dodgers game was awesome
# ['9/10 ']
# hi
# ['I had of that actually ']
# Current loss: 0.5450427 at iteration 7050
# what are you up to
# ['is my storing ']
# what are you up to
# ['is my storing ']
# Current loss: 0.6325759 at iteration 7100
# hey how are you
# ['I had is that scale does that on his that if they passed though. ']
# what are you up to
# ['is my storing ']
# Current loss: 0.7086334 at iteration 7150
# hey how are you
# ['I had is that scale does that delicious. ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 0.7593794 at iteration 7200
# whats up
# []
# hi
# ['I had a my does of ']
# Current loss: 0.80763674 at iteration 7250
# hey how are you
# ['I had is that scale scale does that haha. Ents everywhere! ']
# hi
# ['I had a my does of ']
# Current loss: 0.6200384 at iteration 7300
# whats up
# []
# hey how are you
# ['I had is that scale scale does that haha. Ents everywhere! ']
# Current loss: 0.65171266 at iteration 7350
# that dodgers game was awesome
# ['9/10 ']
# what are you up to
# ['is my storing ']
# Current loss: 0.54087406 at iteration 7400
# that dodgers game was awesome
# ['9/10 ']
# hey how are you
# ['I had is that scale scale does that haha. Ents everywhere! ']
# Current loss: 0.6234129 at iteration 7450
# hey how are you
# ['I had is that scale scale does that haha. Ents everywhere! ']
# what are you up to
# ['is my storing ']
# Current loss: 0.767006 at iteration 7500
# whats up
# []
# hi
# ['I had a there of that 3rd on ']
# Current loss: 0.40951064 at iteration 7550
# hi
# ['I had a there of that 3rd on ']
# hi
# ['I had a there of that 3rd on ']
# Current loss: 0.71673113 at iteration 7600
# that dodgers game was awesome
# ['9/10 ']
# hi
# ['I had a there of that 3rd on ']
# Current loss: 0.7061715 at iteration 7650
# whats up
# []
# whats up
# []
# Current loss: 0.60165113 at iteration 7700
# whats up
# []
# hi
# ['I had a there that 3rd on ']
# Current loss: 0.622744 at iteration 7750
# hi
# ['I had a there of that point on ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 0.382634 at iteration 7800
# that dodgers game was awesome
# ['9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 0.7977643 at iteration 7850
# that dodgers game was awesome
# ['9/10 ']
# what are you up to
# ['is my storing ']
# Current loss: 0.5664001 at iteration 7900
# hi
# ['I had a there that 3rd on ']
# what are you up to
# ['is my storing it ']
# Current loss: 0.65243155 at iteration 7950
# hey how are you
# ['I had is that video that on that on lol.. 9/10 ']
# whats up
# []
# Current loss: 0.5972946 at iteration 8000
# hey how are you
# ['I had is that video that on that on lol.. 9/10 ']
# whats up
# []
# Current loss: 0.7849064 at iteration 8050
# hey how are you
# ['I had is that video that on that on lol.. 9/10 ']
# hi
# ['I had a there that 3rd on that point on lol.. 9/10 ']
# Current loss: 0.4946526 at iteration 8100
# hey how are you
# ['I had is that video that on that on lol.. 9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 0.37110814 at iteration 8150
# what are you up to
# ['is my storing it that forehead ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 0.3691926 at iteration 8200
# hey how are you
# ['I had is that video that on that on lol.. 9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 0.41731992 at iteration 8250
# hey how are you
# ['I had is that video that on that on lol.. 9/10 ']
# hi
# ['I had a there that 3rd on from that point on lol.. 9/10 ']
# Current loss: 0.6174524 at iteration 8300
# hey how are you
# ['I had is that video that on that on lol.. 9/10 ']
# hey how are you
# ['I had is that video that on that on lol.. 9/10 ']
# Current loss: 0.50192493 at iteration 8350
# hi
# ['I had a there that 3rd on of newlinechar ']
# what are you up to
# ['is my last last drink. that first step is ']
# Current loss: 0.45669618 at iteration 8400
# hey how are you
# ['I had is that video that on that on lol.. 9/10 ']
# whats up
# []
# Current loss: 0.41536224 at iteration 8450
# hi
# ['I had a there that 3rd on from that point on lol.. 9/10 ']
# what are you up to
# ['is my last last drink. that first step is indeed ']
# Current loss: 0.39045748 at iteration 8500
# whats up
# []
# hey how are you
# ['I had is that video that on that subreddit ']
# Current loss: 0.38687536 at iteration 8550
# hi
# ['I had a there that 3rd on from that point on lol.. 9/10 ']
# hi
# ['I had a there that 3rd on from that point on lol.. 9/10 ']
# Current loss: 0.39923874 at iteration 8600
# that dodgers game was awesome
# ['9/10 ']
# what are you up to
# ['is my last last drink. that first step is ']
# Current loss: 0.38846716 at iteration 8650
# whats up
# []
# hey how are you
# ['I had is that video that on that subreddit ']
# Current loss: 0.44301713 at iteration 8700
# what are you up to
# ['is my last last drink. that first step is ']
# what are you up to
# ['is my last last drink. that first step is ']
# Current loss: 0.4286722 at iteration 8750
# hey how are you
# ['I had that video that take that on lol.. 9/10 ']
# what are you up to
# ['is my last last drink. that first step is ']
# Current loss: 0.33985248 at iteration 8800
# what are you up to
# ['is my last last drink. that first step is ']
# whats up
# []
# Current loss: 0.26862532 at iteration 8850
# hi
# ['I had a there that 3rd on from that point on lol.. 9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 0.24555252 at iteration 8900
# that dodgers game was awesome
# ['9/10 ']
# what are you up to
# ['is my last last drink. that first step is ']
# Current loss: 0.2317348 at iteration 8950
# hey how are you
# ['I had that video that video has a if subreddit ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 0.3199368 at iteration 9000
# whats up
# []
# hi
# ['I had a there that 3rd on that point on lol.. 9/10 ']
# Current loss: 0.32094622 at iteration 9050
# what are you up to
# ['is my last last drink. that first step is ']
# hey how are you
# ['I had that video that take a if subreddit ']
# Current loss: 0.21401703 at iteration 9100
# hey how are you
# ['I had that video that video has a giant subreddit ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 0.438975 at iteration 9150
# that dodgers game was awesome
# ['9/10 ']
# hey how are you
# ['I had that video that video has a his 9/10 ']
# Current loss: 0.36869523 at iteration 9200
# hi
# ['I had a there that 3rd on from that point on lol.. 9/10 ']
# hey how are you
# ['I had that video that take a his 9/10 ']
# Current loss: 0.31147766 at iteration 9250
# what are you up to
# ['it that Damn that scale handy Ents everywhere! ']
# whats up
# []
# Current loss: 0.3244944 at iteration 9300
# whats up
# []
# whats up
# []
# Current loss: 0.35408607 at iteration 9350
# hey how are you
# ['I had that video that take a his 9/10 ']
# whats up
# []
# Current loss: 0.47869036 at iteration 9400
# whats up
# []
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 0.33501503 at iteration 9450
# hi
# ['I had one of those. ']
# whats up
# []
# Current loss: 0.25128117 at iteration 9500
# that dodgers game was awesome
# ['9/10 ']
# hey how are you
# ['I had that video that take a his 9/10 ']
# Current loss: 0.383814 at iteration 9550
# hi
# ['I had one of those. ']
# what are you up to
# ['is my last drink. that first handy haha. Ents everywhere! ']
# Current loss: 0.20458841 at iteration 9600
# that dodgers game was awesome
# ['9/10 ']
# hey how are you
# ['I had that video that take a his 9/10 ']
# Current loss: 0.24121004 at iteration 9650
# what are you up to
# ['is that last drink. that first handy haha. Ents everywhere! ']
# whats up
# []
# Current loss: 0.528342 at iteration 9700
# what are you up to
# ['is that last drink. that first handy haha. Ents everywhere! ']
# hey how are you
# ['I had that video that take has 9/10 ']
# Current loss: 0.32870874 at iteration 9750
# that dodgers game was awesome
# ['9/10 ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 0.1772145 at iteration 9800
# what are you up to
# ['is that last drink. that first handy haha. Ents everywhere! ']
# that dodgers game was awesome
# ['9/10 ']
# Current loss: 0.24381071 at iteration 9850
# that dodgers game was awesome
# ['9/10 ']
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-7103ab00bf60> in <module>
#     226     feedDict.update({feedPrevious: False})
#     227
# --> 228     curLoss, _, pred = sess.run([loss, optimizer, decoderPrediction], feed_dict=feedDict)
#     229
#     230     if (i % 50 == 0):
#
# ~/anaconda3/envs/codehub/lib/python3.7/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda3/envs/codehub/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# ~/anaconda3/envs/codehub/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda3/envs/codehub/lib/python3.7/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# ~/anaconda3/envs/codehub/lib/python3.7/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda3/envs/codehub/lib/python3.7/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
